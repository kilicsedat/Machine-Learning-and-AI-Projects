# %%
import cv2
import numpy as np
import pandas as pd
from google.colab.patches import cv2_imshow
import dlib

from openpyxl import Workbook, load_workbook
from openpyxl.utils.dataframe import dataframe_to_rows
from openpyxl.drawing.image import Image as OpenpyxlImage
import tempfile
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/sample\ data
# Out:
# /content/drive/MyDrive/sample data

# %%
pwd
# Out:
# '/content/drive/MyDrive/sample data'

# %%
# !wget http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2
# !bzip2 -d shape_predictor_68_face_landmarks.dat.bz2
# Out:
# --2024-02-22 15:16:56--  http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64040097 (61M)
# Saving to: ‘shape_predictor_68_face_landmarks.dat.bz2’
#
# shape_predictor_68_ 100%[===================>]  61.07M  8.57MB/s    in 16s
#
# 2024-02-22 15:17:13 (3.79 MB/s) - ‘shape_predictor_68_face_landmarks.dat.bz2’ saved [64040097/64040097]
#
# bzip2: Output file shape_predictor_68_face_landmarks.dat already exists.

# %%
def find_intersection(line1_point1, line1_point2, line2_point1, line2_point2):
    """
    Finds the intersection point of two lines given by two points on each line.

    Parameters:
    - line1_point1, line1_point2: Points on the first line (numpy arrays or tuples).
    - line2_point1, line2_point2: Points on the second line (numpy arrays or tuples).

    Returns:
    - A tuple (x, y) representing the intersection point.
    """
    x1, y1 = line1_point1
    x2, y2 = line1_point2
    x3, y3 = line2_point1
    x4, y4 = line2_point2

    # Calculating the determinant of the system
    den = (x1 - x2) * (y3 - y4) - (y1 - y2) * (x3 - x4)

    # If the lines are parallel (denominator is 0), there is no intersection
    if den == 0:
        return None

    # Calculating the intersection point
    intersect_x = ((x1*y2 - y1*x2)*(x3 - x4) - (x1 - x2)*(x3*y4 - y3*x4)) / den
    intersect_y = ((x1*y2 - y1*x2)*(y3 - y4) - (y1 - y2)*(x3*y4 - y3*x4)) / den

    return (intersect_x, intersect_y)

# %%
def calculate_distance(p1, p2):
    """Calculate the Euclidean distance between two points."""
    return np.sqrt((p1[0] - p2[0]) ** 2 + (p1[1] - p2[1]) ** 2)

# %%
# Load the pre-trained model for facial landmark detection
predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')
detector = dlib.get_frontal_face_detector()

# Load the image
image = cv2.imread('yuz_a.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect faces in the image
faces = detector(gray, 1)

# Initialize the lists to hold point descriptions and their corresponding distances
points = []
distances = []

for face in faces:
    # Determine the facial landmarks for the face region
    shape = predictor(gray, face)

    # Get the coordinates for landmarks 28 and 30
    point_28 = (shape.part(27).x, shape.part(27).y)
    point_31 = (shape.part(30).x, shape.part(30).y)

    cv2.circle(image, (point_28), 3, (255, 0, 0), -1)  # Draws a red dot
    cv2.circle(image, (point_31), 3, (255, 0, 0), -1)  # Draws a red dot

    # Calculate the direction vector of the line
    direction = np.array([point_31[0] - point_28[0], point_31[1] - point_28[1]])

    # Extend the line to the top and bottom of the face
    top_point = np.array(point_28) - direction * 1.5   # Arbitrary large number
    bottom_point = np.array(point_31) + direction * 2.5 # Arbitrary large number

    # Draw the extended line
    cv2.line(image, tuple(top_point.astype(int)), tuple(bottom_point.astype(int)), (255, 0, 0), 2)


    # Calculate and draw symmetry for each facial landmark
    for i in ([0,1,2,3,4, 5, 6, 7]):
        original_point = (shape.part(i).x, shape.part(i).y)

        cv2.circle(image, original_point, 3, (0, 255, 0), -1)
        facial_point = np.array([shape.part(i).x, shape.part(i).y])

        perp_direction = np.array([-direction[1], direction[0]])  # Rotate the direction vector by 90 degrees
        end_point = facial_point - perp_direction * 3
        #cv2.circle(image, end_point, 3, (0,0,255), -1)
        #cv2.line(image, tuple(facial_point.astype(int)), tuple(end_point.astype(int)), (0, 255, 0), 2)

        """Finds the intersection of two lines given in form of ([x1, y1], [x2, y2])."""
        intersect_point  = find_intersection(top_point, bottom_point, facial_point, end_point)
        intersect_point = np.array(intersect_point).astype(int)

        cv2.circle(image, intersect_point, 3, (0,0,255), -1)
        cv2.line(image, tuple(facial_point.astype(int)), tuple(intersect_point), (0, 255, 0), 2)

        distance = calculate_distance(facial_point, intersect_point)
        print(f'Distance between facial point \'{i}\' and its intersection point: {distance}')

        points.append(f'Point {i}')
        distances.append(distance)

    for i in ([9, 10,11,12,13,14,15,16]):
        original_point = (shape.part(i).x, shape.part(i).y)

        cv2.circle(image, original_point, 3, (0, 255, 0), -1)
        facial_point = np.array([shape.part(i).x, shape.part(i).y])

        perp_direction = np.array([direction[1], -direction[0]])  # Rotate the direction vector by 270 degrees
        end_point = facial_point - perp_direction * 3
        #cv2.circle(image, end_point, 3, (0,0,255), -1)
        #cv2.line(image, tuple(end_point.astype(int)), tuple(facial_point.astype(int)), (0, 0, 0), 2)

        intersect_point  = find_intersection(top_point, bottom_point, end_point, facial_point)
        intersect_point = np.array(intersect_point).astype(int)

        cv2.circle(image, intersect_point, 3, (0,0,255), -1)
        cv2.line(image, tuple(intersect_point), tuple(facial_point.astype(int)), (0, 255, 0), 2)

        distance = calculate_distance(facial_point, intersect_point)
        print(f'Distance between facial point \'{i}\' and its intersection point: {distance}')

        points.append(f'Point {i}')
        distances.append(distance)


print(f'points:{points}')
print(f'distance:{distances}')
# Out:
# Distance between facial point '0' and its intersection point: 515.8342757126557
# Distance between facial point '1' and its intersection point: 523.8950276534413
# Distance between facial point '2' and its intersection point: 509.76268988618614
# Distance between facial point '3' and its intersection point: 491.7570538385799
# Distance between facial point '4' and its intersection point: 466.58011102060493
# Distance between facial point '5' and its intersection point: 410.25967386522404
# Distance between facial point '6' and its intersection point: 320.8067954392488
# Distance between facial point '7' and its intersection point: 197.12178976460214
# Distance between facial point '9' and its intersection point: 114.5294721894762
# Distance between facial point '10' and its intersection point: 232.24340679554285
# Distance between facial point '11' and its intersection point: 328.76283244916846
# Distance between facial point '12' and its intersection point: 394.03553139279205
# Distance between facial point '13' and its intersection point: 431.2505072460785
# Distance between facial point '14' and its intersection point: 454.4370143375207
# Distance between facial point '15' and its intersection point: 473.5419727964988
# Distance between facial point '16' and its intersection point: 482.59714048054616
# points:['Point 0', 'Point 1', 'Point 2', 'Point 3', 'Point 4', 'Point 5', 'Point 6', 'Point 7', 'Point 9', 'Point 10', 'Point 11', 'Point 12', 'Point 13', 'Point 14', 'Point 15', 'Point 16']
# distance:[515.8342757126557, 523.8950276534413, 509.76268988618614, 491.7570538385799, 466.58011102060493, 410.25967386522404, 320.8067954392488, 197.12178976460214, 114.5294721894762, 232.24340679554285, 328.76283244916846, 394.03553139279205, 431.2505072460785, 454.4370143375207, 473.5419727964988, 482.59714048054616]

# %%
# Create a DataFrame
df = pd.DataFrame({
    'Point': points,
    'Distance': distances
})

# Save DataFrame to Excel
excel_path = 'facemetrics_all_patients.xlsx'
df.to_excel(excel_path, index=False)

# Save your image to a temporary file
temp_image_path = tempfile.mktemp(suffix='.png')
cv2.imwrite(temp_image_path, image)  # Assuming 'image' is your cv2 image

# Load the workbook and get the active sheet
wb = load_workbook(excel_path)
ws = wb.active

# Insert the image into the Excel file
img = OpenpyxlImage(temp_image_path)
# Adjust as needed; 'A' + str(len(distances) + 2) positions the image below the data
img.anchor = 'A' + str(len(distances) + 2)
ws.add_image(img)

# Save the workbook
wb.save(excel_path)

# Optionally, clean up the temporary image file
os.remove(temp_image_path)

# %%
# Display the image
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
class FacialLandmarkProcessor:
    def __init__(self, predictor_path):
        self.predictor_path = predictor_path
        self.predictor = dlib.shape_predictor(predictor_path)
        self.detector = dlib.get_frontal_face_detector()

    def find_intersection(self, line1_point1, line1_point2, line2_point1, line2_point2):
        x1, y1 = line1_point1
        x2, y2 = line1_point2
        x3, y3 = line2_point1
        x4, y4 = line2_point2

        # Calculating the determinant of the system
        den = (x1 - x2) * (y3 - y4) - (y1 - y2) * (x3 - x4)

        # If the lines are parallel (denominator is 0), there is no intersection
        if den == 0:
            return None

        # Calculating the intersection point
        intersect_x = ((x1*y2 - y1*x2)*(x3 - x4) - (x1 - x2)*(x3*y4 - y3*x4)) / den
        intersect_y = ((x1*y2 - y1*x2)*(y3 - y4) - (y1 - y2)*(x3*y4 - y3*x4)) / den

        return (intersect_x, intersect_y)


    def calculate_distance(self, p1, p2):
        """Calculate the Euclidean distance between two points."""
        return np.sqrt((p1[0] - p2[0]) ** 2 + (p1[1] - p2[1]) ** 2)

    def process_image(self, image_path):
        image = cv2.imread(image_path)
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        faces = self.detector(gray, 1)

        points = []
        distances = []


        for face in faces:
            shape = self.predictor(gray, face)
            # Get the coordinates for landmarks 28 and 30
            point_28 = (shape.part(27).x, shape.part(27).y)
            point_31 = (shape.part(30).x, shape.part(30).y)

            cv2.circle(image, (point_28), 3, (255, 0, 0), -1)  # Draws a red dot
            cv2.circle(image, (point_31), 3, (255, 0, 0), -1)  # Draws a red dot

            # Calculate the direction vector of the line
            direction = np.array([point_31[0] - point_28[0], point_31[1] - point_28[1]])

            # Extend the line to the top and bottom of the face
            top_point = np.array(point_28) - direction * 1.5   # Arbitrary large number
            bottom_point = np.array(point_31) + direction * 2.5 # Arbitrary large number

            # Draw the extended line
            cv2.line(image, tuple(top_point.astype(int)), tuple(bottom_point.astype(int)), (255, 0, 0), 2)


            # Calculate and draw symmetry for each facial landmark
            for i in ([0,1,2,3,4, 5, 6, 7]):
                original_point = (shape.part(i).x, shape.part(i).y)

                cv2.circle(image, original_point, 3, (0, 255, 0), -1)
                facial_point = np.array([shape.part(i).x, shape.part(i).y])

                perp_direction = np.array([-direction[1], direction[0]])  # Rotate the direction vector by 90 degrees
                end_point = facial_point - perp_direction * 3
                #cv2.circle(image, end_point, 3, (0,0,255), -1)
                #cv2.line(image, tuple(facial_point.astype(int)), tuple(end_point.astype(int)), (0, 255, 0), 2)

                """Finds the intersection of two lines given in form of ([x1, y1], [x2, y2])."""
                intersect_point  = self.find_intersection(top_point, bottom_point, facial_point, end_point)
                intersect_point = np.array(intersect_point).astype(int)

                cv2.circle(image, intersect_point, 3, (0,0,255), -1)
                cv2.line(image, tuple(facial_point.astype(int)), tuple(intersect_point), (0, 255, 0), 2)

                distance = self.calculate_distance(facial_point, intersect_point)
                print(f'Distance between facial point \'{i}\' and its intersection point: {distance}')

                points.append(f'Point {i}')
                distances.append(distance)

            for i in ([9, 10,11,12,13,14,15,16]):
                original_point = (shape.part(i).x, shape.part(i).y)

                cv2.circle(image, original_point, 3, (0, 255, 0), -1)
                facial_point = np.array([shape.part(i).x, shape.part(i).y])

                perp_direction = np.array([direction[1], -direction[0]])  # Rotate the direction vector by 270 degrees
                end_point = facial_point - perp_direction * 3
                #cv2.circle(image, end_point, 3, (0,0,255), -1)
                #cv2.line(image, tuple(end_point.astype(int)), tuple(facial_point.astype(int)), (0, 0, 0), 2)

                intersect_point  = self.find_intersection(top_point, bottom_point, end_point, facial_point)
                intersect_point = np.array(intersect_point).astype(int)

                cv2.circle(image, intersect_point, 3, (0,0,255), -1)
                cv2.line(image, tuple(intersect_point), tuple(facial_point.astype(int)), (0, 255, 0), 2)

                distance = self.calculate_distance(facial_point, intersect_point)
                print(f'Distance between facial point \'{i}\' and its intersection point: {distance}')

                points.append(f'Point {i}')
                distances.append(distance)
        print(len(distances))

        # Return the modified image, points list, and distances list
        return image, points, distances


    def calculate_symetry(self, distances):
        distances = np.array(distances)

        # Calculate symmetry using vectorized operations
        symmetries = (1 - distances[:8] / distances[15:7:-1]) ** 2
        symmetry_metric = np.mean(symmetries)

        return symmetry_metric


    def save_data_to_excel(self, image_paths, excel_path):
        wb = load_workbook(excel_path) if os.path.exists(excel_path) else Workbook()
        for idx, image_path in enumerate(image_paths):
            image, points, distances = self.process_image(image_path)

            symetry_metric = self.calculate_symetry(distances)

            ws = wb.create_sheet(f"Face {idx + 1}")
            df = pd.DataFrame({'Point': points, 'Distance': distances, 'Symetry_Value': symetry_metric})
            for r in dataframe_to_rows(df, index=False, header=True):
                ws.append(r)
            temp_image_path = tempfile.mktemp(suffix='.png')
            cv2.imwrite(temp_image_path, image)
            img = OpenpyxlImage(temp_image_path)
            img.anchor = 'A' + str(len(distances) + 2)
            ws.add_image(img)

        wb.save(excel_path)


# Example usage
predictor_path = 'shape_predictor_68_face_landmarks.dat'
processor = FacialLandmarkProcessor(predictor_path)
image_paths = ['1.jpg', '2.jpg', '3.jpg', '4.jpg', '5.jpg', '6.jpg', '7.jpg', '8.jpg','9.jpg', '10.jpg', '11.jpg', '12.jpg', '13.jpg', '14.jpg', '15.jpg', '16.jpg']
excel_path = 'facemetrics_all_patients.xlsx'
processor.save_data_to_excel(image_paths, excel_path)
# Out:
# Distance between facial point '0' and its intersection point: 350.0014285685131
# Distance between facial point '1' and its intersection point: 340.00147058505496
# Distance between facial point '2' and its intersection point: 328.0015243867016
# Distance between facial point '3' and its intersection point: 314.00159235265033
# Distance between facial point '4' and its intersection point: 292.00171232374646
# Distance between facial point '5' and its intersection point: 250.00199999200007
# Distance between facial point '6' and its intersection point: 194.0
# Distance between facial point '7' and its intersection point: 124.0
# Distance between facial point '9' and its intersection point: 48.010415536631214
# Distance between facial point '10' and its intersection point: 125.00399993600205
# Distance between facial point '11' and its intersection point: 190.0026315607234
# Distance between facial point '12' and its intersection point: 247.00809703327542
# Distance between facial point '13' and its intersection point: 283.0070670495703
# Distance between facial point '14' and its intersection point: 307.00651458886017
# Distance between facial point '15' and its intersection point: 331.0060422409235
# Distance between facial point '16' and its intersection point: 346.0057802985378
# 16
# Distance between facial point '0' and its intersection point: 356.0056179332006
# Distance between facial point '1' and its intersection point: 347.00576364089403
# Distance between facial point '2' and its intersection point: 332.0060240417333
# Distance between facial point '3' and its intersection point: 315.0063491423625
# Distance between facial point '4' and its intersection point: 289.0069203323685
# Distance between facial point '5' and its intersection point: 245.0081631293129
# Distance between facial point '6' and its intersection point: 184.00271737123884
# Distance between facial point '7' and its intersection point: 107.00467279516349
# Distance between facial point '9' and its intersection point: 90.0
# Distance between facial point '10' and its intersection point: 172.0
# Distance between facial point '11' and its intersection point: 234.00213674238105
# Distance between facial point '12' and its intersection point: 285.00175438056516
# Distance between facial point '13' and its intersection point: 318.0015723231569
# Distance between facial point '14' and its intersection point: 339.0014749230451
# Distance between facial point '15' and its intersection point: 357.0014005574768
# Distance between facial point '16' and its intersection point: 369.00135501106223
# 16
# Distance between facial point '0' and its intersection point: 407.82962128810607
# Distance between facial point '1' and its intersection point: 385.8108344772085
# Distance between facial point '2' and its intersection point: 361.7319449537185
# Distance between facial point '3' and its intersection point: 337.71733742880303
# Distance between facial point '4' and its intersection point: 298.60509037858014
# Distance between facial point '5' and its intersection point: 227.43130831088317
# Distance between facial point '6' and its intersection point: 143.28293687665675
# Distance between facial point '7' and its intersection point: 42.04759208325728
# Distance between facial point '9' and its intersection point: 185.4561942885705
# Distance between facial point '10' and its intersection point: 275.5884612969128
# Distance between facial point '11' and its intersection point: 354.81262660734046
# Distance between facial point '12' and its intersection point: 407.89459422747933
# Distance between facial point '13' and its intersection point: 425.9213542427757
# Distance between facial point '14' and its intersection point: 423.9257010373398
# Distance between facial point '15' and its intersection point: 428.9149099763262
# Distance between facial point '16' and its intersection point: 434.9678149012867
# 16
# Distance between facial point '0' and its intersection point: 358.16895454519783
# Distance between facial point '1' and its intersection point: 346.1444785057245
# Distance between facial point '2' and its intersection point: 329.1519405988669
# Distance between facial point '3' and its intersection point: 309.13104017552166
# Distance between facial point '4' and its intersection point: 271.1180554666177
# Distance between facial point '5' and its intersection point: 212.08488866489287
# Distance between facial point '6' and its intersection point: 136.0588108135596
# Distance between facial point '7' and its intersection point: 51.0098029794274
# Distance between facial point '9' and its intersection point: 132.09466302617983
# Distance between facial point '10' and its intersection point: 202.12125073826354
# Distance between facial point '11' and its intersection point: 268.1510768205118
# Distance between facial point '12' and its intersection point: 313.15970366571753
# Distance between facial point '13' and its intersection point: 333.1816321467917
# Distance between facial point '14' and its intersection point: 335.18054836162554
# Distance between facial point '15' and its intersection point: 338.178946713127
# Distance between facial point '16' and its intersection point: 340.177894637497
# 16
# Distance between facial point '0' and its intersection point: 375.0653276430654
# Distance between facial point '1' and its intersection point: 368.06657006579667
# Distance between facial point '2' and its intersection point: 353.0693982774491
# Distance between facial point '3' and its intersection point: 336.05356715857073
# Distance between facial point '4' and its intersection point: 306.0588178765644
# Distance between facial point '5' and its intersection point: 260.0480724789169
# Distance between facial point '6' and its intersection point: 200.0399960007998
# Distance between facial point '7' and its intersection point: 123.03657992645927
# Distance between facial point '9' and its intersection point: 77.00649323271382
# Distance between facial point '10' and its intersection point: 160.0124995117569
# Distance between facial point '11' and its intersection point: 227.01982292302142
# Distance between facial point '12' and its intersection point: 279.0286723618202
# Distance between facial point '13' and its intersection point: 309.04045042680093
# Distance between facial point '14' and its intersection point: 328.03810754240124
# Distance between facial point '15' and its intersection point: 347.03602118512134
# Distance between facial point '16' and its intersection point: 361.04985805287333
# 16
# Distance between facial point '0' and its intersection point: 458.10915729769033
# Distance between facial point '1' and its intersection point: 455.1098768429444
# Distance between facial point '2' and its intersection point: 443.11285244280606
# Distance between facial point '3' and its intersection point: 426.1173547275445
# Distance between facial point '4' and its intersection point: 399.1014908516379
# Distance between facial point '5' and its intersection point: 358.0893743187586
# Distance between facial point '6' and its intersection point: 298.08220342717544
# Distance between facial point '7' and its intersection point: 211.05923339195564
# Distance between facial point '9' and its intersection point: 41.0
# Distance between facial point '10' and its intersection point: 149.03019828209315
# Distance between facial point '11' and its intersection point: 238.05251521460553
# Distance between facial point '12' and its intersection point: 312.05768697470023
# Distance between facial point '13' and its intersection point: 363.0674868395682
# Distance between facial point '14' and its intersection point: 404.0792001575929
# Distance between facial point '15' and its intersection point: 435.09309348689965
# Distance between facial point '16' and its intersection point: 454.08919828597556
# 16
# Distance between facial point '0' and its intersection point: 319.0767932645682
# Distance between facial point '1' and its intersection point: 309.0792778560219
# Distance between facial point '2' and its intersection point: 291.06184909740404
# Distance between facial point '3' and its intersection point: 270.06665843824555
# Distance between facial point '4' and its intersection point: 239.0522955338434
# Distance between facial point '5' and its intersection point: 187.04277585621958
# Distance between facial point '6' and its intersection point: 122.03687967167957
# Distance between facial point '7' and its intersection point: 52.03844732503075
# Distance between facial point '9' and its intersection point: 120.01666550941998
# Distance between facial point '10' and its intersection point: 192.02343606966312
# Distance between facial point '11' and its intersection point: 251.04979585731593
# Distance between facial point '12' and its intersection point: 295.0423698386386
# Distance between facial point '13' and its intersection point: 323.05572274763995
# Distance between facial point '14' and its intersection point: 339.05309318748294
# Distance between facial point '15' and its intersection point: 352.0695953927291
# Distance between facial point '16' and its intersection point: 353.0693982774491
# 16
# Distance between facial point '0' and its intersection point: 415.1457575358322
# Distance between facial point '1' and its intersection point: 405.14935517658176
# Distance between facial point '2' and its intersection point: 386.12951195162486
# Distance between facial point '3' and its intersection point: 362.1380952067871
# Distance between facial point '4' and its intersection point: 321.1261434389919
# Distance between facial point '5' and its intersection point: 251.09759058979438
# Distance between facial point '6' and its intersection point: 165.07574019219177
# Distance between facial point '7' and its intersection point: 73.02739212103907
# Distance between facial point '9' and its intersection point: 136.03308421115798
# Distance between facial point '10' and its intersection point: 219.0570701894828
# Distance between facial point '11' and its intersection point: 290.0844704564517
# Distance between facial point '12' and its intersection point: 340.0941046239996
# Distance between facial point '13' and its intersection point: 374.1082730975085
# Distance between facial point '14' and its intersection point: 396.1262425035736
# Distance between facial point '15' and its intersection point: 415.12046444375636
# Distance between facial point '16' and its intersection point: 422.1184667839113
# 16
# Distance between facial point '0' and its intersection point: 408.0600446012817
# Distance between facial point '1' and its intersection point: 402.06094065452316
# Distance between facial point '2' and its intersection point: 385.06363110530185
# Distance between facial point '3' and its intersection point: 366.06693377031473
# Distance between facial point '4' and its intersection point: 328.05487345869443
# Distance between facial point '5' and its intersection point: 271.0461215365385
# Distance between facial point '6' and its intersection point: 200.0399960007998
# Distance between facial point '7' and its intersection point: 119.03780911962384
# Distance between facial point '9' and its intersection point: 65.00769185258002
# Distance between facial point '10' and its intersection point: 144.01388821915754
# Distance between facial point '11' and its intersection point: 215.02092921387907
# Distance between facial point '12' and its intersection point: 273.02930245671433
# Distance between facial point '13' and its intersection point: 308.0405817420815
# Distance between facial point '14' and its intersection point: 327.0382240656281
# Distance between facial point '15' and its intersection point: 346.0361252817399
# Distance between facial point '16' and its intersection point: 358.05027579936313
# 16
# Distance between facial point '0' and its intersection point: 303.0594001181947
# Distance between facial point '1' and its intersection point: 295.0610106401725
# Distance between facial point '2' and its intersection point: 281.06404963993526
# Distance between facial point '3' and its intersection point: 269.04646438858845
# Distance between facial point '4' and its intersection point: 246.05080776132397
# Distance between facial point '5' and its intersection point: 204.0392119177096
# Distance between facial point '6' and its intersection point: 147.03060905811415
# Distance between facial point '7' and its intersection point: 81.00617260431454
# Distance between facial point '9' and its intersection point: 79.02531240052139
# Distance between facial point '10' and its intersection point: 153.05227865013967
# Distance between facial point '11' and its intersection point: 216.05786262017867
# Distance between facial point '12' and its intersection point: 259.0694887477103
# Distance between facial point '13' and its intersection point: 280.08748633239577
# Distance between facial point '14' and its intersection point: 288.0850568842473
# Distance between facial point '15' and its intersection point: 299.0819285747636
# Distance between facial point '16' and its intersection point: 307.07979419037
# 16
# Distance between facial point '0' and its intersection point: 385.0831079130841
# Distance between facial point '1' and its intersection point: 381.08398024582453
# Distance between facial point '2' and its intersection point: 373.08578102093355
# Distance between facial point '3' and its intersection point: 359.0891254271006
# Distance between facial point '4' and its intersection point: 333.073565447635
# Distance between facial point '5' and its intersection point: 285.0631508981826
# Distance between facial point '6' and its intersection point: 211.05923339195564
# Distance between facial point '7' and its intersection point: 128.03515142334936
# Distance between facial point '9' and its intersection point: 82.00609733428362
# Distance between facial point '10' and its intersection point: 181.02486017119307
# Distance between facial point '11' and its intersection point: 269.04646438858845
# Distance between facial point '12' and its intersection point: 330.0545409474016
# Distance between facial point '13' and its intersection point: 368.06657006579667
# Distance between facial point '14' and its intersection point: 385.06363110530185
# Distance between facial point '15' and its intersection point: 399.0801924425716
# Distance between facial point '16' and its intersection point: 409.0782321268146
# 16
# Distance between facial point '0' and its intersection point: 344.28476585524373
# Distance between facial point '1' and its intersection point: 337.2906758272455
# Distance between facial point '2' and its intersection point: 325.25989608311687
# Distance between facial point '3' and its intersection point: 307.2751210234893
# Distance between facial point '4' and its intersection point: 281.2561110447202
# Distance between facial point '5' and its intersection point: 242.20652344641752
# Distance between facial point '6' and its intersection point: 195.1640335717624
# Distance between facial point '7' and its intersection point: 133.13526955694348
# Distance between facial point '9' and its intersection point: 44.01136216933077
# Distance between facial point '10' and its intersection point: 122.06555615733703
# Distance between facial point '11' and its intersection point: 194.12624758130983
# Distance between facial point '12' and its intersection point: 250.1619475459847
# Distance between facial point '13' and its intersection point: 287.2107240337658
# Distance between facial point '14' and its intersection point: 310.23217112349903
# Distance between facial point '15' and its intersection point: 326.2207841324645
# Distance between facial point '16' and its intersection point: 338.2499076126999
# 16
# Distance between facial point '0' and its intersection point: 412.146818500398
# Distance between facial point '1' and its intersection point: 408.1225306204008
# Distance between facial point '2' and its intersection point: 398.1256083197864
# Distance between facial point '3' and its intersection point: 386.12951195162486
# Distance between facial point '4' and its intersection point: 357.1134273588715
# Distance between facial point '5' and its intersection point: 305.1048999934285
# Distance between facial point '6' and its intersection point: 233.0772404161333
# Distance between facial point '7' and its intersection point: 147.05441169852742
# Distance between facial point '9' and its intersection point: 71.00704190430693
# Distance between facial point '10' and its intersection point: 183.04371062672436
# Distance between facial point '11' and its intersection point: 280.06427833624196
# Distance between facial point '12' and its intersection point: 350.09141663285607
# Distance between facial point '13' and its intersection point: 390.10383233185496
# Distance between facial point '14' and its intersection point: 413.12104763616196
# Distance between facial point '15' and its intersection point: 426.1173547275445
# Distance between facial point '16' and its intersection point: 431.11599367223664
# 16
# Distance between facial point '0' and its intersection point: 375.26124233658874
# Distance between facial point '1' and its intersection point: 371.2640569729313
# Distance between facial point '2' and its intersection point: 365.2683944717911
# Distance between facial point '3' and its intersection point: 359.23529893372114
# Distance between facial point '4' and its intersection point: 335.2148564726808
# Distance between facial point '5' and its intersection point: 280.178514522438
# Distance between facial point '6' and its intersection point: 200.12246250733574
# Distance between facial point '7' and its intersection point: 105.07616285342742
# Distance between facial point '9' and its intersection point: 126.09916732476864
# Distance between facial point '10' and its intersection point: 223.1815404552984
# Distance between facial point '11' and its intersection point: 301.23910768690047
# Distance between facial point '12' and its intersection point: 357.2744043448957
# Distance between facial point '13' and its intersection point: 377.2982904811523
# Distance between facial point '14' and its intersection point: 390.2883549377306
# Distance between facial point '15' and its intersection point: 402.318281960937
# Distance between facial point '16' and its intersection point: 405.3159261613094
# 16
# Distance between facial point '0' and its intersection point: 399.3619911809335
# Distance between facial point '1' and its intersection point: 399.3619911809335
# Distance between facial point '2' and its intersection point: 387.3306081372863
# Distance between facial point '3' and its intersection point: 363.30978516962625
# Distance between facial point '4' and its intersection point: 333.29416436535456
# Distance between facial point '5' and its intersection point: 291.247317584214
# Distance between facial point '6' and its intersection point: 231.21634890292685
# Distance between facial point '7' and its intersection point: 148.16544806398016
# Distance between facial point '9' and its intersection point: 74.02702209328699
# Distance between facial point '10' and its intersection point: 163.11039206623224
# Distance between facial point '11' and its intersection point: 232.17450333746814
# Distance between facial point '12' and its intersection point: 283.21370023358685
# Distance between facial point '13' and its intersection point: 320.22492095400696
# Distance between facial point '14' and its intersection point: 352.27829907617075
# Distance between facial point '15' and its intersection point: 376.29908317719827
# Distance between facial point '16' and its intersection point: 390.2883549377306
# 16
# Distance between facial point '0' and its intersection point: 361.00554012369395
# Distance between facial point '1' and its intersection point: 352.00568177232594
# Distance between facial point '2' and its intersection point: 338.00591710797016
# Distance between facial point '3' and its intersection point: 321.00623046912966
# Distance between facial point '4' and its intersection point: 296.00675667964066
# Distance between facial point '5' and its intersection point: 249.00803199896987
# Distance between facial point '6' and its intersection point: 188.0026595556563
# Distance between facial point '7' and its intersection point: 109.00458705944443
# Distance between facial point '9' and its intersection point: 88.0
# Distance between facial point '10' and its intersection point: 166.0
# Distance between facial point '11' and its intersection point: 228.0021929719098
# Distance between facial point '12' and its intersection point: 280.0017857085915
# Distance between facial point '13' and its intersection point: 312.00160255998685
# Distance between facial point '14' and its intersection point: 333.0015014981164
# Distance between facial point '15' and its intersection point: 353.00141642775316
# Distance between facial point '16' and its intersection point: 368.00135869314397
# 16
